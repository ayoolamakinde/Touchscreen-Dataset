# %%
import glob
import numpy as np
import pandas as pd
from sklearn.model_selection import LeaveOneOut

# %%
df = pd.read_csv('touchscreen-data.csv')
loo = LeaveOneOut()
for train, test in loo.split(df):
    print("%s %s" % (train, test))
# Out:
# [    1     2     3 ... 21155 21156 21157] [0]
# [    0     2     3 ... 21155 21156 21157] [1]
# [    0     1     3 ... 21155 21156 21157] [2]
# [    0     1     2 ... 21155 21156 21157] [3]
# [    0     1     2 ... 21155 21156 21157] [4]
# [    0     1     2 ... 21155 21156 21157] [5]
# [    0     1     2 ... 21155 21156 21157] [6]
# [    0     1     2 ... 21155 21156 21157] [7]
# [    0     1     2 ... 21155 21156 21157] [8]
# [    0     1     2 ... 21155 21156 21157] [9]
# [    0     1     2 ... 21155 21156 21157] [10]
# [    0     1     2 ... 21155 21156 21157] [11]
# [    0     1     2 ... 21155 21156 21157] [12]
# [    0     1     2 ... 21155 21156 21157] [13]
# [    0     1     2 ... 21155 21156 21157] [14]
# [    0     1     2 ... 21155 21156 21157] [15]
# [    0     1     2 ... 21155 21156 21157] [16]
# [    0     1     2 ... 21155 21156 21157] [17]
# [    0     1     2 ... 21155 21156 21157] [18]
# [    0     1     2 ... 21155 21156 21157] [19]
# ...
