# %%
import pandas as pd
import glob

# %%
df = pd.concat([pd.read_csv(f) for f in glob.glob('interactions-UID_*.csv')], ignore_index = True)

# %%
df
# Out:
#        interStrokeTime  strokeDuration    startX  startY     stopX     stopY  \
# 0                0.913           0.320  27.79800 -35.647   5.88670 -36.73700
# 1               10.818           0.172  27.58000 -31.069   4.57850 -36.73700
# 2                0.759           0.277   5.01460 -40.553  34.44800 -32.48600
# 3                1.143           0.250   3.59740 -37.391  34.55700 -30.41500
# 4                0.528           0.261  31.06900 -29.215   3.81550 -38.04500
# 5                1.440           0.135  27.47100 -29.215   9.26610 -34.66600
# 6                2.123           0.040  11.55500 -11.446  11.55500 -11.44600
# 7                0.546           0.135   6.32270 -37.282  34.66600 -34.55700
# 8                1.845           0.141   8.93910 -39.463  32.37700 -34.12100
# 9                0.592           0.232  34.77500 -31.396   5.45060 -39.68100
# 10               3.323           0.165  29.21500 -34.993  12.10000 -40.77100
# ...
